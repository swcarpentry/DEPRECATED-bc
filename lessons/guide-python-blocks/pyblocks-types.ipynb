# %%
temp_fahr = 98.6
temp_kelvin = (temp_fahr - 32.0) * (5.0 / 9.0) + 273.15
print 'body temperature in Kelvin:', temp_kelvin
# Out:
# body temperature in Kelvin: 310.15

# %%
temp_fahr = 98.6
temp_kelvin = (temp_fahr - 32.0) * (5 / 9) + 273.15
print 'body temperature in Kelvin:', temp_kelvin
# Out:
# body temperature in Kelvin: 273.15

# %%
print 5/9
# Out:
# 0

# %%
10/3
# Out:
# 3

# %%
10.0/3
# Out:
# 3.3333333333333335

# %%
10 % 3
# Out:
# 1

# %%
15 % 6
# Out:
# 3

# %%
type(12)
# Out:
# int

# %%
type(12.0)
# Out:
# float

# %%
name = "Alan Turing"
born = 'June 23, 1912'
print name, born
# Out:
# Alan Turing June 23, 1912

# %%
full = name + " (" + born + ")"
print full
# Out:
# Alan Turing (June 23, 1912)

# %%
print "xo" * 3
# Out:
# xoxoxo

# %%
print 2 + "three"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-f6f99c093ec8> in <module>()
# ----> 1 print 2 + "three"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print 2 + int("3")
# Out:
# 5

# %%
print str(2) + "3"
# Out:
# 23

# %%
temp = 'temperature'
print temp, type(temp)
# Out:
# temperature <type 'str'>

# %%
temp = 37.2
print temp, type(temp)
# Out:
# 37.2 <type 'float'>
