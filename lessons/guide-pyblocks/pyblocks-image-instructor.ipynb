# %% [markdown]
# # Basic Programming Using Python: Images (Instructor Version)

# %% [markdown]
# ## Objectives
#
# FIXME

# %% [markdown]
# ## Lesson
#
# We now have almost everything we need to create the altered images
# Valerie needs for her experiments. The only thing we're missing is some
# actual image processing. Luckily, that's easy to add given what we've
# already learned:

# %%
from skimage import novice
flower = novice.open('flower.png')
flower.show()
# Out:
# Image([[[ 42,  20,  30, 255],
#         [ 42,  20,  30, 255],
#         [ 44,  21,  31, 255],
#         ...,
#         [ 14,  14,  13, 255],
#         [ 14,  14,  12, 255],
#         [ 14,  14,  12, 255]],
#
#        [[ 46,  23,  32, 255],
#         [ 46,  23,  32, 255],
#         [ 47,  23,  33, 255],
#         ...,
#         [ 14,  14,  13, 255],
#         [ 14,  14,  12, 255],
#         [ 14,  14,  13, 255]],
#
#        [[ 48,  23,  34, 255],
#         [ 49,  24,  34, 255],
#         [ 49,  24,  34, 255],
#         ...,
#         [ 15,  15,  14, 255],
#         [ 14,  14,  13, 255],
#         [ 14,  14,  13, 255]],
#
#        ...,
#        [[ 83,  34,  58, 255],
#         [ 86,  37,  61, 255],
#         [ 84,  34,  61, 255],
#         ...,
#         [  4,   4,   4, 255],
#         [  4,   4,   4, 255],
#         [  4,   4,   4, 255]],
#
#        [[ 77,  33,  56, 255],
#         [ 82,  34,  58, 255],
#         [ 80,  33,  57, 255],
#         ...,
#         [  4,   4,   4, 255],
# ...

# %% [markdown]
# The first statement asks Python to find a library called `skimage` (the
# SciKit image processing library) and load its `novice` module. The
# second statement asks `novice` to open an file called `flower.png` and
# assign the result to the variable `flower`. Finally, we ask that image
# to display itself. If all has gone well, this shows a picture of the
# world's cutest child.
#
# Like block grids, images have properties:

# %%
print 'format:', flower.format
print 'size:', flower.size
print 'width:', flower.width
print 'path:', flower.path
# Out:
# format: PNG
# size: (240, 180)
# width: 240
# path: /Users/gwilson/bc/lessons/guide-pyblocks/flower.png

# %% [markdown]
# Unlike blocks grids, though, we can change some of the properties related to sizing:

# %%
flower.size = (400, 100)
flower.show()
# Out:
# skimage.dtype_converter: WARNING: Possible precision loss when converting from float64 to uint8
# Image([[[  0,   0,   0,   0],
#         [ 42,  20,  30, 255],
#         [ 42,  20,  30, 255],
#         ...,
#         [ 14,  14,  12, 255],
#         [ 14,  14,  12, 255],
#         [  0,   0,   0,   0]],
#
#        [[  0,   0,   0,   0],
#         [ 48,  23,  34, 255],
#         [ 49,  24,  34, 255],
#         ...,
#         [ 14,  14,  13, 255],
#         [ 14,  14,  13, 255],
#         [  0,   0,   0,   0]],
#
#        [[  0,   0,   0,   0],
#         [ 50,  24,  33, 255],
#         [ 51,  24,  34, 255],
#         ...,
#         [ 15,  15,  14, 255],
#         [ 15,  15,  14, 255],
#         [  0,   0,   0,   0]],
#
#        ...,
#        [[  0,   0,   0,   0],
#         [ 85,  38,  58, 255],
#         [ 88,  40,  62, 255],
#         ...,
#         [  4,   4,   4, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0,   0]],
#
#        [[  0,   0,   0,   0],
# ...

# %% [markdown]
# We can also modify the colors of particular pixels:

# %%
for pixel in flower:
    pixel.red = 0
flower.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-ce0b3167675b> in <module>()
# ----> 1 for pixel in flower:
#       2     pixel.red = 0
#       3 flower.show()
#
# /Users/gwilson/anaconda/lib/python2.7/site-packages/scikit_image-0.9dev-py2.7-macosx-10.5-x86_64.egg/skimage/novice/novice.pyc in __iter__(self)
#     347         """Iterates over all pixels in the image"""
#     348         for x in xrange(self.width):
# --> 349             for y in xrange(self.height):
#     350                 yield self._makepixel((x, y))
#     351
#
# ValueError: cannot copy sequence with size 3 to array axis with dimension 4

# %% [markdown]
# Once we make changes, the picture object in memory knows that it has
# been modified, and its `path` is set to `None` to show that it doesn't
# correspond to a file on disk any longer:

# %%
print 'modified:', flower.modified
print 'path:', flower.path
# Out:
# modified: True
# path: None

# %% [markdown]
# We can easily save it to disk:

# %%
flower.save('/tmp/blue-green-flower.png')
print 'modified:', flower.modified
print 'path:', flower.path
# Out:
# modified: False
# path: /tmp/blue-green-flower.png

# %% [markdown]
# And yes, we can select individual pixels or entire slices, but the
# results may surprise you:

# %%
flower[0:100, 0:50] = (0, 0, 0)
flower.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-c22fffc7b9a7> in <module>()
# ----> 1 flower[0:100, 0:50] = (0, 0, 0)
#       2 flower.show()
#
# /Users/gwilson/anaconda/lib/python2.7/site-packages/scikit_image-0.9dev-py2.7-macosx-10.5-x86_64.egg/skimage/novice/novice.pyc in __setitem__(self, key, value)
#     379         if isinstance(key, tuple) and len(key) == 2:
#     380             if isinstance(value, tuple):
# --> 381                 self[key[0], key[1]].rgb = value
#     382             elif isinstance(value, PixelGroup):
#     383                 src_key = self[key[0], key[1]]._key
#
# /Users/gwilson/anaconda/lib/python2.7/site-packages/scikit_image-0.9dev-py2.7-macosx-10.5-x86_64.egg/skimage/novice/novice.pyc in rgb(self, value)
#     185     def rgb(self, value):
#     186         """Gets or sets the color with an (r, g, b) tuple"""
# ...

# %% [markdown]
# Like `ipythonblocks.ImageGrid`, `skimage.novice` uses a standard Cartesian coordinate system.
#
# Let's generate some images:

# %%
BASE    = 128
STEP    = 4
SPACING = 4
NUMBER  = 6
GRAY    = (BASE, BASE, BASE)
SIZE    = 200

for color in range(BASE + STEP, BASE + NUMBER * STEP, STEP):
    image = novice.Picture(size=(SIZE, SIZE), color=GRAY)
    image[::SPACING, ::SPACING] = (color, color, color)
    filename = 'step-' + str(color) + '.png'
    image.save(filename)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-9a440e662926> in <module>()
#       8 for color in range(BASE + STEP, BASE + NUMBER * STEP, STEP):
#       9     image = novice.Picture(size=(SIZE, SIZE), color=GRAY)
# ---> 10     image[::SPACING, ::SPACING] = (color, color, color)
#      11     filename = 'step-' + str(color) + '.png'
#      12     image.save(filename)
#
# /Users/gwilson/anaconda/lib/python2.7/site-packages/scikit_image-0.9dev-py2.7-macosx-10.5-x86_64.egg/skimage/novice/novice.pyc in __setitem__(self, key, value)
#     379         if isinstance(key, tuple) and len(key) == 2:
#     380             if isinstance(value, tuple):
# --> 381                 self[key[0], key[1]].rgb = value
#     382             elif isinstance(value, PixelGroup):
#     383                 src_key = self[key[0], key[1]]._key
#
# ...

# %% [markdown]
# This program creates files with names like `step-132.png`,
# `step-136.png`, and so on. Each one has white pixels spaced evenly
# across a gray background, with the white slowly getting whiter. Images
# like these are sometimes used in vision tests, since different spacings
# and colorings are noticeable to different people.
#
# Having told you that, we've spoiled the second part of our experiment,
# which is to see how much knowing what a program does helps you figure
# out how it works. As you might suspect, the answer is, "A lot." Let's go
# through this one.
#
# The constants at the top don't tell us much, although `GRAY` is
# obviously an RGB color value and `SIZE` is (probably) an image size.
# Next is our loop: given the name of its index variable, `color`, we can
# guess that we're looping over colors, and sure enough, two lines down,
# we see `(color, color, color)`, which is creating a shade of gray
# defined by the current value of `color`.
#
# Backing up a line, we're creating a `SIZE`×`SIZE` image using
# `novice.new` and setting all its pixels to the fixed color `GRAY`. The
# loop is going from `BASE + STEP` up to `BASE + NUMBER * STEP` in
# increments of `STEP`. `BASE` is 128—our initial shade of gray. `STEP` is
# 4: that's the increment each time we go around the loop. And `NUMBER` is
# how many we're doing, so this loop is creating a bunch of images with
# the same gray background, but whiter and whiter points spaced at equal
# intervals across them.

# %% [markdown]
# ## Key Points
#
# FIXME
