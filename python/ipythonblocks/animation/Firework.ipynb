# %% [markdown]
# A simple firework animation with [`ipythonblocks`](https://github.com/jiffyclub/ipythonblocks).

# %%
from ipythonblocks import BlockGrid

# %%
import math
import itertools

# %%
def dist(p1, p2):
    return math.sqrt((p1[0] - p2[0]) ** 2 + (p1[1] - p2[1]) ** 2)

# %%
grid = BlockGrid(41, 41, block_size=8, lines_on=False)

red = (255, 43, 43)
orange = (255, 142, 43)
yellow = (248, 255, 43)
black = (0, 0, 0)
gray = (188, 188, 188)
blue = (15, 183, 255)
pink = (255, 79, 249)
green = (76, 224, 133)

counter = itertools.count(0)
frame_fmt = 'frame{:02}.txt'

# launch explosion
launch_center = (40, 20)

for i in (1, 2, 3, 2, 1):
    for block in grid:
        if dist((block.row, block.col), launch_center) < i*3:
            block.rgb = yellow
        else:
            block.rgb = black
        
        if dist((block.row, block.col), launch_center) < i*2:
            block.rgb = orange
        
        if dist((block.row, block.col), launch_center) < i:
            block.rgb = red

    grid.to_text(frame_fmt.format(counter.next()))
    grid.flash()

# ascent
for i in range(17):
    grid[:, :] = black
    row = 36 - i
    grid[row:row + 2, 20] = gray
    grid.to_text(frame_fmt.format(counter.next()))
    grid.flash()
    
# firework
firework_center = (20, 20)
colors = itertools.cycle((blue, pink, green))

for i in range(0, 20):
    grid[:, :] = black
    for j in range(0, i, 2):
        color = colors.next()
        for block in grid:
            if round(dist((block.row, block.col), firework_center)) == j:
                block.rgb = color
    grid.to_text(frame_fmt.format(counter.next()))
    grid.flash()

grid.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksa6a59373-0ab1-4596-bdbc-b89c9b7bf79d td {border: 0px solid white;}</style><table id="blocksa6a59373-0ab1-4596-bdbc-b89c9b7bf79d" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 20]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 21]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 22]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 23]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 24]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 25]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 26]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 27]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 28]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 29]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 30]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 31]&#10;Color: (0, 0, 0)" style="width: 8px; height: 8px;background-color: rgb(0, ...
